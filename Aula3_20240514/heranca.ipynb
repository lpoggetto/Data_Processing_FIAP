# %% [markdown]
# ### Herança em Classes

# %%
"""
POO - Herança (Inheritance)

Cliente
    - nome;
    - sobrenome;
    - cpf;
    - renda;

Funcionario
    - nome;
    - sobrenome;
    - cpf;
    - matricula;

Perguntar: Existe alguma entidade genérica o suciente para encapsular os atributos
e métodos comuns a outras entidades?
"""

# %%
class Cliente:

    def __init__(self, nome, sobrenome, cpf, renda):
        self.__nome = nome
        self.__sobrenome = sobrenome
        self.__cpf = cpf
        self.__renda = renda

    def nome_completo(self):
        return f'{self.__nome} {self.__sobrenome}'


class Funcionario:

    def __init__(self, nome, sobrenome, cpf, matricula):
        self.__nome = nome
        self.__sobrenome = sobrenome
        self.__cpf = cpf
        self.__matricula = matricula

    def nome_completo(self):
        return f'{self.__nome} {self.__sobrenome}'


cliente1 = Cliente('José', 'Isaque', '123.456.789-00', 5000)
funcionario1 = Funcionario('Daisy', 'Cristina', '987.654.321-11', 1234)

print(cliente1.nome_completo())
print(funcionario1.nome_completo())

# %%
"""
OBS: Quando uma classe herda de outra classe ela herda TODOS os atributos e métodos da classe herdada.

Quando uma classe herda de outra classe, a classe herdada é conhecida por:
    [Pessoa]
    - Super Classe;
    - Classe Mãe;
    - Classe Pai;
    - Classe Base;
    - Classe Genérica;

Quando uma classe herda de outra classe, ela é chamada:
    [Cliente, Funcionario]
    - Sub Classe;
    - Classe Filha;
    - Classe Específica;
"""    

class Pessoa:

    def __init__(self, nome, sobrenome, cpf):
        self.__nome = nome
        self.__sobrenome = sobrenome
        self.__cpf = cpf

    def nome_completo(self):
        return f'{self.__nome} {self.__sobrenome}'


class Cliente(Pessoa):
    # Cliente herda de Pessoa

    def __init__(self, nome, sobrenome, cpf, renda):
        Pessoa.__init__(self, nome, sobrenome, cpf)  # Forma não comum de acessar dados da super classe
        self.__renda = renda


class Funcionario(Pessoa):
    #  Funcionario herda de Pessoa

    def __init__(self, nome, sobrenome, cpf, matricula):
        super().__init__(nome, sobrenome, cpf)  # Forma comum de acessar dados da super classe
        self.__matricula = matricula


cliente1 = Cliente('José', 'Isaque', '123.456.789-00', 5000)
funcionario1 = Funcionario('Daisy', 'Cristina', '987.654.321-11', 1234)

print(cliente1.nome_completo())
print(funcionario1.nome_completo())

print(cliente1.__dict__)

print(funcionario1.__dict__)

# %% [markdown]
# ## Exercícios
#
# #### Suponha que você esteja desenvolvendo um sistema para uma loja de produtos eletrônicos. Escreva duas classes: Produto e Eletronico.
#
# 1) A classe Produto deve ter os seguintes atributos:
#
#     nome: o nome do produto.<br>
#     preco: o preço do produto.<br>
#
#     Além disso, a classe deve ter um método mostrar_informacoes() que imprime na tela o nome e o preço do produto.<br>
#
# 2) A classe Eletronico deve herdar da classe Produto e adicionar o seguinte atributo:
#
#     marca: a marca do produto eletrônico.
#
#     A classe Eletronico também deve sobrescrever o método mostrar_informacoes() para imprimir na tela o nome, o preço e a marca do produto eletrônico.
#
# Escreva também um programa que cria uma instância de Produto e uma instância de Eletronico, preenchendo os atributos com informações fictícias, e em seguida chama o método mostrar_informacoes() para cada uma das instâncias criadas.

# %% [markdown]
# Duplo_clique __aqui__ para a solução.
# <!-- resposta abaixo:
# class Produto:
#     def __init__(self, nome, preco):
#         self.nome = nome
#         self.preco = preco
#
#     def mostrar_informacoes(self):
#         print(f"Nome: {self.nome}")
#         print(f"Preço: R$ {self.preco:.2f}")
#         print()
#
# class Eletronico(Produto):
#     def __init__(self, nome, preco, marca):
#         super().__init__(nome, preco)
#         self.marca = marca
#
#     def mostrar_informacoes(self):
#         print(f"Nome: {self.nome}")
#         print(f"Preço: R$ {self.preco:.2f}")
#         print(f"Marca: {self.marca}")
#         print()
#
# # Criando instâncias da classe Produto e Eletronico
# produto1 = Produto("Livro", 29.90)
# eletronico1 = Eletronico("Smartphone", 1499.99, "Samsung")
#
# # Chamando o método mostrar_informacoes() para cada produto
# print("Informações do Produto:")
# produto1.mostrar_informacoes()
#
# print("Informações do Eletrônico:")
# eletronico1.mostrar_informacoes()
#
# -->
